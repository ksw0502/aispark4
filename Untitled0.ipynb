# %%
import pandas as pd 
import numpy as np
import tensorflow as tf

# visualisations
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid', context='notebook')
# %matplotlib notebook

# misc
import random as rn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=('/content/drive/MyDrive/csv/train_data.csv')
df=pd.read_csv(data)
df.head()
# Out:
#    air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0        1.59         41.00           0.7          20.53     1680.0
# 1        2.97         59.28           0.7          38.40     3142.0
# 2        1.91         45.29           0.7          24.73     2023.0
# 3        2.37         51.33           0.7          30.63     2506.0
# 4        1.90         45.21           0.7          24.65     2017.0
#
#    motor_temp  motor_vibe  type
# 0       58.67        2.93     0
# 1       74.91        3.75     0
# 2       62.48        3.12     0
# 3       67.84        3.39     0
# 4       62.41        3.12     0

# %%
df
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           1.59         41.00           0.7          20.53     1680.0
# 1           2.97         59.28           0.7          38.40     3142.0
# 2           1.91         45.29           0.7          24.73     2023.0
# 3           2.37         51.33           0.7          30.63     2506.0
# 4           1.90         45.21           0.7          24.65     2017.0
# ...          ...           ...           ...            ...        ...
# 2458        2.28         50.20           0.7          29.53     2416.0
# 2459        2.04         46.94           0.7          26.34     2155.0
# 2460        1.19         35.74           0.7          15.39     1259.0
# 2461        1.21         36.00           0.7          15.64     1280.0
# 2462        2.72         55.99           0.7          35.19     2879.0
#
#       motor_temp  motor_vibe  type
# 0          58.67        2.93     0
# 1          74.91        3.75     0
# 2          62.48        3.12     0
# 3          67.84        3.39     0
# 4          62.41        3.12     0
# ...          ...         ...   ...
# 2458       66.84        3.34     7
# 2459       63.94        3.20     7
# 2460       53.99        2.70     7
# 2461       54.22        2.71     7
# 2462       71.99        3.60     7
#
# [2463 rows x 8 columns]

# %%
df = df
RANDOM_SEED = 42
TRAINING_SAMPLE = len(df)
VALIDATE_SIZE = 0.2

# setting random seeds for libraries to ensure reproducibility
np.random.seed(RANDOM_SEED)
rn.seed(RANDOM_SEED)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463 entries, 0 to 2462
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   air_inflow     2463 non-null   float64
#  1   air_end_temp   2463 non-null   float64
#  2   out_pressure   2463 non-null   float64
#  3   motor_current  2463 non-null   float64
#  4   motor_rpm      2463 non-null   float64
#  5   motor_temp     2463 non-null   float64
#  6   motor_vibe     2463 non-null   float64
#  7   type           2463 non-null   int64
# dtypes: float64(7), int64(1)
# memory usage: 154.1 KB

# %%
df.head()
# Out:
#    air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0        1.59         41.00           0.7          20.53     1680.0
# 1        2.97         59.28           0.7          38.40     3142.0
# 2        1.91         45.29           0.7          24.73     2023.0
# 3        2.37         51.33           0.7          30.63     2506.0
# 4        1.90         45.21           0.7          24.65     2017.0
#
#    motor_temp  motor_vibe  type
# 0       58.67        2.93     0
# 1       74.91        3.75     0
# 2       62.48        3.12     0
# 3       67.84        3.39     0
# 4       62.41        3.12     0

# %%
df.describe()
# Out:
#         air_inflow  air_end_temp  out_pressure  motor_current    motor_rpm  \
# count  2463.000000   2463.000000  2.463000e+03    2463.000000  2463.000000
# mean      2.128843     49.001137  7.000000e-01      27.490715  2372.576939
# std       1.202328      8.725091  1.110448e-16      13.604597   687.870774
# min       0.330000     32.030000  7.000000e-01       5.340000  1201.000000
# 25%       1.280000     41.600000  7.000000e-01      17.110000  1784.500000
# 50%       1.960000     48.980000  7.000000e-01      25.850000  2358.000000
# 75%       2.820000     56.355000  7.000000e-01      36.000000  2971.000000
# max       6.220000     64.960000  7.000000e-01      72.000000  3564.000000
#
#         motor_temp   motor_vibe         type
# count  2463.000000  2463.000000  2463.000000
# mean     65.766707     3.452972     2.957369
# std       7.797152     1.576386     2.230113
# min      50.360000     1.970000     0.000000
# 25%      59.150000     2.880000     1.000000
# 50%      65.640000     3.260000     3.000000
# 75%      72.275000     3.730000     5.000000
# max      80.520000    21.870000     7.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463 entries, 0 to 2462
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   air_inflow     2463 non-null   float64
#  1   air_end_temp   2463 non-null   float64
#  2   out_pressure   2463 non-null   float64
#  3   motor_current  2463 non-null   float64
#  4   motor_rpm      2463 non-null   float64
#  5   motor_temp     2463 non-null   float64
#  6   motor_vibe     2463 non-null   float64
#  7   type           2463 non-null   int64
# dtypes: float64(7), int64(1)
# memory usage: 154.1 KB

# %%
plt.figure(figsize=(20,8))
df.hist()
plt.show()
# Out:
# <div id='c62cbf59-0e4e-4a0a-a20d-501e6191cdea'></div>
# <div id='490148df-78a1-4ac5-b672-d7f64c7429cd'></div>

# %%
df.boxplot()
plt.show()

# %%
df.shape
# Out:
# (2463, 8)

# %%
# 설비 번호 [0, 4, 5, 6, 7]: 30HP(마력)
# 설비 번호 1: 20HP
# 설비 번호 2: 10HP
# 설비 번호 3: 50HP
##1:1  2:1  3:1
mapping = {0:0, 1:1, 2:1, 3:1, 4:0, 5:0, 6:0, 7:0}
df['label'] = df['type'].map(mapping)
df
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           1.59         41.00           0.7          20.53     1680.0
# 1           2.97         59.28           0.7          38.40     3142.0
# 2           1.91         45.29           0.7          24.73     2023.0
# 3           2.37         51.33           0.7          30.63     2506.0
# 4           1.90         45.21           0.7          24.65     2017.0
# ...          ...           ...           ...            ...        ...
# 2458        2.28         50.20           0.7          29.53     2416.0
# 2459        2.04         46.94           0.7          26.34     2155.0
# 2460        1.19         35.74           0.7          15.39     1259.0
# 2461        1.21         36.00           0.7          15.64     1280.0
# 2462        2.72         55.99           0.7          35.19     2879.0
#
#       motor_temp  motor_vibe  type  label
# 0          58.67        2.93     0      0
# 1          74.91        3.75     0      0
# 2          62.48        3.12     0      0
# 3          67.84        3.39     0      0
# 4          62.41        3.12     0      0
# ...          ...         ...   ...    ...
# 2458       66.84        3.34     7      0
# 2459       63.94        3.20     7      0
# 2460       53.99        2.70     7      0
# 2461       54.22        2.71     7      0
# 2462       71.99        3.60     7      0
#
# [2463 rows x 9 columns]

# %%
df['label'].value_counts()
# Out:
# 0    1422
# 1    1041
# Name: label, dtype: int64

# %%
from imblearn.over_sampling import SMOTE, ADASYN

X = df.drop('label', axis=1)
y = df.loc[:,'label']

#SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

df = pd.concat([X_resampled, y_resampled], axis=1)

#ADASYN
#adasyn = ADASYN()
#X_resampled, y_resampled = adasyn.fit_resample(X, y)
#df = pd.concat([X_resampled, y_resampled], axis=1)

# %%
df['label'].value_counts()
# Out:
# 0    1422
# 1    1422
# Name: label, dtype: int64

# %%
# manual parameter 
RATIO_TO_FRAUD = 15

# splitting by class
fraud = df[df.label == 1]
clean = df[df.label == 0]

# concatenate with fraud transactions into a single dataframe
visualisation_initial = pd.concat([fraud, clean])
column_names = list(visualisation_initial.drop('label', axis=1).columns)

# isolate features from labels 
features, labels = visualisation_initial.drop('label', axis=1).values, \
                   visualisation_initial.label.values
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

def tsne_scatter(features, labels, dimensions=2, save_as='graph.png'):
    if dimensions not in (2, 3):
        raise ValueError('tsne_scatter can only plot in 2d or 3d (What are you? An alien that can visualise >3d?). Make sure the "dimensions" argument is in (2, 3)')

    # t-SNE dimensionality reduction
    features_embedded = TSNE(n_components=dimensions, random_state=RANDOM_SEED).fit_transform(features)
    
    # initialising the plot
    fig, ax = plt.subplots(figsize=(8,8))
    
    # counting dimensions
    if dimensions == 3: ax = fig.add_subplot(111, projection='3d')

    # plotting data
    ax.scatter(
        *zip(*features_embedded[np.where(labels==1)]),
        marker='o',
        color='r',
        s=2,
        alpha=0.7,
        label='Fraud'
    )
    ax.scatter(
        *zip(*features_embedded[np.where(labels==0)]),
        marker='o',
        color='g',
        s=2,
        alpha=0.3,
        label='Clean'
    )

    # storing it to be displayed later
    plt.legend(loc='best')
    plt.savefig(save_as);
    plt.show;

tsne_scatter(features, labels, dimensions=2, save_as='tsne_initial_2d.png')
# Out:
# <div id='3126830e-f8a4-4a85-98df-7ec58ae8a2a1'></div>

# %%
clean.shape, fraud.shape
# Out:
# ((1422, 9), (1422, 9))

# %%
X_train = clean.iloc[:].drop('label', axis=1)

X_test = clean.iloc[:].append(fraud).sample(frac=1)
# Out:
# <ipython-input-19-bd97f21b5848>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   X_test = clean.iloc[:].append(fraud).sample(frac=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((1422, 8), (2844, 9))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val = train_test_split(X_train, test_size=0.2,
                                  random_state=RANDOM_SEED)

X_test, y_test = X_test.drop('label', axis=1).values, X_test.label.values
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn.pipeline import Pipeline

# configure our pipeline
pipeline = Pipeline([('normalizer', Normalizer()),
                     ('scaler',MinMaxScaler())])

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1137, 8), (285, 8), (2844, 8))

# %%
# get normalization parameters by fitting to the training data
pipeline.fit(X_train);
# transform the training and validation data with these parameters
X_train_transformed = pipeline.transform(X_train)
X_validate_transformed = pipeline.transform(X_val)

# %%
X_train_transformed.shape
# Out:
# (1137, 8)

# %%
from tensorflow.keras import backend as K
tf.keras.backend.clear_session()

# data dimensions // hyperparameters 
input_dim = X_train_transformed.shape[1]
BATCH_SIZE = 16
EPOCHS = 100

# define the custom activation function
def selu(x):
    alpha = 1.67326
    scale = 1.0507
    return scale * K.elu(x, alpha)

autoencoder = tf.keras.models.Sequential([
 # deconstruct / encode
    tf.keras.layers.Dense(64, activation=selu, input_shape=(input_dim, )),
    tf.keras.layers.Dense(32,activation=selu),
    tf.keras.layers.Dense(16, activation=selu),
    tf.keras.layers.Dense(8, activation=selu),
    tf.keras.layers.Dense(4, activation=selu),

    # reconstruction / decode
    tf.keras.layers.Dense(8, activation=selu),
    tf.keras.layers.Dense(16, activation=selu),
    tf.keras.layers.Dense(32, activation=selu),
    tf.keras.layers.Dense(64, activation=selu),
    tf.keras.layers.Dense(input_dim, activation=selu)
])   

# https://keras.io/api/models/model_training_apis/
autoencoder.compile(optimizer="adam", 
                    loss="mse",
                    metrics=["acc"])

# print an overview of our model
autoencoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                576
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 4)                 36
#
#  dense_5 (Dense)             (None, 8)                 40
#
#  dense_6 (Dense)             (None, 16)                144
#
#  dense_7 (Dense)             (None, 32)                544
#
#  dense_8 (Dense)             (None, 64)                2112
#
#  dense_9 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 6,716
# Trainable params: 6,716
# Non-trainable params: 0
# _________________________________________________________________

# %%
# define our early stopping
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=10,
    verbose=1, 
    mode='min',
    restore_best_weights=True
)

# %%
history = autoencoder.fit(
    X_train_transformed, X_train_transformed,
    shuffle=True,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    validation_data=(X_validate_transformed, X_validate_transformed)
);
# Out:
# Epoch 1/100
# 72/72 [==============================] - 9s 11ms/step - loss: 0.0808 - acc: 0.3843 - val_loss: 0.0110 - val_acc: 0.4667
# Epoch 2/100
# 72/72 [==============================] - 1s 7ms/step - loss: 0.0083 - acc: 0.4591 - val_loss: 0.0071 - val_acc: 0.4772
# Epoch 3/100
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0060 - acc: 0.4837 - val_loss: 0.0056 - val_acc: 0.5228
# Epoch 4/100
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0051 - acc: 0.5013 - val_loss: 0.0046 - val_acc: 0.6140
# Epoch 5/100
# 72/72 [==============================] - 0s 6ms/step - loss: 0.0037 - acc: 0.5708 - val_loss: 0.0037 - val_acc: 0.5088
# Epoch 6/100
# 72/72 [==============================] - 1s 7ms/step - loss: 0.0029 - acc: 0.5875 - val_loss: 0.0021 - val_acc: 0.6175
# Epoch 7/100
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0019 - acc: 0.6209 - val_loss: 0.0016 - val_acc: 0.6070
# Epoch 8/100
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0016 - acc: 0.6157 - val_loss: 0.0013 - val_acc: 0.6421
# Epoch 9/100
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0014 - acc: 0.6394 - val_loss: 0.0020 - val_acc: 0.6421
# Epoch 10/100
# 72/72 [==============================] - 0s 6ms/step - loss: 0.0013 - acc: 0.6306 - val_loss: 0.0014 - val_acc: 0.6421
# Epoch 11/100
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0012 - acc: 0.6570 - val_loss: 0.0010 - val_acc: 0.6632
# Epoch 12/100
# 72/72 [==============================] - 1s 7ms/step - loss: 0.0012 - acc: 0.6517 - val_loss: 0.0013 - val_acc: 0.6211
# Epoch 13/100
# 72/72 [==============================] - 1s 10ms/step - loss: 0.0012 - acc: 0.6227 - val_loss: 0.0015 - val_acc: 0.4456
# Epoch 14/100
# 72/72 [==============================] - 1s 10ms/step - loss: 0.0011 - acc: 0.6297 - val_loss: 0.0013 - val_acc: 0.6561
# Epoch 15/100
# 72/72 [==============================] - 1s 11ms/step - loss: 0.0011 - acc: 0.6684 - val_loss: 9.3384e-04 - val_acc: 0.7018
# Epoch 16/100
# 72/72 [==============================] - 1s 10ms/step - loss: 0.0010 - acc: 0.6623 - val_loss: 0.0015 - val_acc: 0.6316
# Epoch 17/100
# 72/72 [==============================] - 1s 8ms/step - loss: 0.0012 - acc: 0.6561 - val_loss: 8.9072e-04 - val_acc: 0.6807
# Epoch 18/100
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0010 - acc: 0.6614 - val_loss: 8.5289e-04 - val_acc: 0.7158
# Epoch 19/100
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0012 - acc: 0.6517 - val_loss: 0.0017 - val_acc: 0.6421
# Epoch 20/100
# 72/72 [==============================] - 1s 7ms/step - loss: 9.8960e-04 - acc: 0.6711 - val_loss: 8.6637e-04 - val_acc: 0.6772
# Epoch 21/100
# 72/72 [==============================] - 0s 7ms/step - loss: 9.2369e-04 - acc: 0.7071 - val_loss: 0.0031 - val_acc: 0.7123
# Epoch 22/100
# 72/72 [==============================] - 1s 8ms/step - loss: 0.0022 - acc: 0.6931 - val_loss: 0.0013 - val_acc: 0.6456
# Epoch 23/100
# 72/72 [==============================] - 0s 7ms/step - loss: 9.2043e-04 - acc: 0.6957 - val_loss: 0.0013 - val_acc: 0.7298
# Epoch 24/100
# 72/72 [==============================] - 0s 7ms/step - loss: 8.1594e-04 - acc: 0.7282 - val_loss: 8.6973e-04 - val_acc: 0.7754
# Epoch 25/100
# 68/72 [===========================>..] - ETA: 0s - loss: 8.4726e-04 - acc: 0.7270Restoring model weights from the end of the best epoch: 15.
# 72/72 [==============================] - 1s 7ms/step - loss: 8.3732e-04 - acc: 0.7318 - val_loss: 0.0012 - val_acc: 0.7018
# Epoch 25: early stopping

# %%
autoencoder.save('/content/drive/MyDrive/csv/model_f.h5')

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Normalizer was fitted with feature names
#   warnings.warn(
# 89/89 [==============================] - 0s 2ms/step

# %%
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
clean.shape, fraud.shape
# Out:
# ((1422, 9), (1422, 9))

# %%
clean = mse[y_test==0]
fraud = mse[y_test==1]

plt.subplot(1,2,1)
plt.hist(clean, bins=50, density=True, label='clean', alpha=.6, color='green')
plt.subplot(1,2,2)
plt.hist(fraud, bins=50, density=True, label='fraud', alpha=.6, color='red')
plt.show()
# Out:
# <ipython-input-32-bbcf3b465143>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %%
clean.max(), fraud.min()
# Out:
# (0.013275799358875608, 212.5172714588644)

# %%
test_data = pd.read_csv('/content/drive/MyDrive/csv/test_data.csv')

test_data.head()
# Out:
#    air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0        2.51         53.28           0.7          32.54     2662.0
# 1        2.66         55.24           0.7          34.45     2819.0
# 2        1.72         42.74           0.7          22.23     1819.0
# 3        2.20         49.15           0.7          28.50     2332.0
# 4        2.06         47.28           0.7          26.67     2182.0
#
#    motor_temp  motor_vibe  type
# 0       69.58        3.48     0
# 1       71.32        3.57     0
# 2       60.21        3.01     0
# 3       65.91        3.30     0
# 4       64.24        3.21     0

# %%
test_data['label'] = 0

test_data.head()
# Out:
#    air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0        2.51         53.28           0.7          32.54     2662.0
# 1        2.66         55.24           0.7          34.45     2819.0
# 2        1.72         42.74           0.7          22.23     1819.0
# 3        2.20         49.15           0.7          28.50     2332.0
# 4        2.06         47.28           0.7          26.67     2182.0
#
#    motor_temp  motor_vibe  type  label
# 0       69.58        3.48     0      0
# 1       71.32        3.57     0      0
# 2       60.21        3.01     0      0
# 3       65.91        3.30     0      0
# 4       64.24        3.21     0      0

# %%
cond = (test_data['type'] == 0) | (test_data['type'] == 4) | (test_data['type'] == 5) | (test_data['type'] == 6) | (test_data['type'] == 7)
X_test = test_data.loc[cond, :].drop('label', axis=1)

# %%
X_test
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           2.51         53.28           0.7          32.54     2662.0
# 1           2.66         55.24           0.7          34.45     2819.0
# 2           1.72         42.74           0.7          22.23     1819.0
# 3           2.20         49.15           0.7          28.50     2332.0
# 4           2.06         47.28           0.7          26.67     2182.0
# ...          ...           ...           ...            ...        ...
# 7384        2.12         48.08           0.7          27.45     2246.0
# 7385        1.48         39.63           0.7          19.19     1570.0
# 7386        1.56         40.61           0.7          20.15     1649.0
# 7387        1.59         40.99           0.7          20.52     1679.0
# 7388        1.70         42.51           0.7          22.01     1801.0
#
#       motor_temp  motor_vibe  type
# 0          69.58        3.48     0
# 1          71.32        3.57     0
# 2          60.21        3.01     0
# 3          65.91        3.30     0
# 4          64.24        3.21     0
# ...          ...         ...   ...
# 7384       64.96        3.25     7
# 7385       57.44        2.87     7
# 7386       58.32        2.92     7
# 7387       58.66        2.93     7
# 7388       60.01        3.00     7
#
# [4266 rows x 8 columns]

# %%
len(X_test)
# Out:
# 4266

# %%
test_data
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           2.51         53.28           0.7          32.54     2662.0
# 1           2.66         55.24           0.7          34.45     2819.0
# 2           1.72         42.74           0.7          22.23     1819.0
# 3           2.20         49.15           0.7          28.50     2332.0
# 4           2.06         47.28           0.7          26.67     2182.0
# ...          ...           ...           ...            ...        ...
# 7384        2.12         48.08           0.7          27.45     2246.0
# 7385        1.48         39.63           0.7          19.19     1570.0
# 7386        1.56         40.61           0.7          20.15     1649.0
# 7387        1.59         40.99           0.7          20.52     1679.0
# 7388        1.70         42.51           0.7          22.01     1801.0
#
#       motor_temp  motor_vibe  type  label
# 0          69.58        3.48     0      0
# 1          71.32        3.57     0      0
# 2          60.21        3.01     0      0
# 3          65.91        3.30     0      0
# 4          64.24        3.21     0      0
# ...          ...         ...   ...    ...
# 7384       64.96        3.25     7      0
# 7385       57.44        2.87     7      0
# 7386       58.32        2.92     7      0
# 7387       58.66        2.93     7      0
# 7388       60.01        3.00     7      0
#
# [7389 rows x 9 columns]

# %%
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
# 134/134 [==============================] - 0s 2ms/step

# %%
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
mean_mse = np.mean(mse)
std_mse = np.std(mse)

print("Mean MSE:", mean_mse)
print("Standard deviation of MSE:", std_mse)
# Out:
# Mean MSE: 12.663465076973113
# Standard deviation of MSE: 63.04034466439372

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# mse 값을 히스토그램으로 시각화
plt.plot(mse)
plt.xlabel('mse')
plt.ylabel('count')
plt.show()

# %%
threshold = 0.04
outliers = np.where(mse >= threshold)[0]

# 이상치 시각화
plt.scatter(range(len(mse)), mse, c='blue', label='normal')
plt.scatter(outliers, mse[outliers], c='red', label='outlier')
plt.xlabel('Index')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
plt.scatter(np.arange(len(mse)), mse)
# mse 값이 10 이상인 데이터를 빨간색으로 표시
plt.scatter(np.where(mse >= 200)[0], mse[mse >= 200], c='r')
plt.xlabel('index')
plt.ylabel('mse')
plt.show()

# %%
import seaborn as sns

plt.hist(mse, bins=100)
plt.xlabel('mse')
plt.ylabel('count')
plt.show()

# %%
max(mse),min(mse)
# Out:
# (0.044868791113503996, 0.0036097599266888885)

# %%
sum=0
for i in mse:
    if i<0.01:
        sum+=1

# %%
sum
# Out:
# 3720

# %%
sns.boxplot(x=mse)

# q3와 iqr 계산
q1, q3 = np.percentile(mse, [25, 75])
iqr = q3 - q1

# q3+1.5*iqr 값 계산
upper_bound = q3 + 1.5 * iqr

print("Upper bound: ", upper_bound)
# Out:
# Upper bound:  0.2604155199401673

# %%
plt.boxplot(mse)
plt.xlabel('MSE')
plt.show()

# %%
threshold=0.01

# %%
test_data.loc[cond, 'label'] = np.where(mse >= 0.008, 1, 0)

# %%
test_data['label'].value_counts()
# Out:
# 0    7085
# 1     304
# Name: label, dtype: int64

# %%
df = pd.read_csv('/content/drive/MyDrive/csv/train_data.csv')

# %%
# 설비 번호 [0, 4, 5, 6, 7]: 30HP(마력)
# 설비 번호 1: 20HP
# 설비 번호 2: 10HP
# 설비 번호 3: 50HP

mapping = {0:1, 1:1, 2:0, 3:1, 4:1, 5:1, 6:1, 7:1}

df['label'] = df['type'].map(mapping)
df
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           1.59         41.00           0.7          20.53     1680.0
# 1           2.97         59.28           0.7          38.40     3142.0
# 2           1.91         45.29           0.7          24.73     2023.0
# 3           2.37         51.33           0.7          30.63     2506.0
# 4           1.90         45.21           0.7          24.65     2017.0
# ...          ...           ...           ...            ...        ...
# 2458        2.28         50.20           0.7          29.53     2416.0
# 2459        2.04         46.94           0.7          26.34     2155.0
# 2460        1.19         35.74           0.7          15.39     1259.0
# 2461        1.21         36.00           0.7          15.64     1280.0
# 2462        2.72         55.99           0.7          35.19     2879.0
#
#       motor_temp  motor_vibe  type  label
# 0          58.67        2.93     0      1
# 1          74.91        3.75     0      1
# 2          62.48        3.12     0      1
# 3          67.84        3.39     0      1
# 4          62.41        3.12     0      1
# ...          ...         ...   ...    ...
# 2458       66.84        3.34     7      1
# 2459       63.94        3.20     7      1
# 2460       53.99        2.70     7      1
# 2461       54.22        2.71     7      1
# 2462       71.99        3.60     7      1
#
# [2463 rows x 9 columns]

# %%
df['label'].value_counts()
# Out:
# 1    2097
# 0     366
# Name: label, dtype: int64

# %%
from imblearn.over_sampling import SMOTE, ADASYN

X = df.drop('label', axis=1)
y = df.loc[:,'label']

#SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

df = pd.concat([X_resampled, y_resampled], axis=1)

#ADASYN
#adasyn = ADASYN()
#X_resampled, y_resampled = adasyn.fit_resample(X, y)
#df = pd.concat([X_resampled, y_resampled], axis=1)

# %%
# manual parameter 
RATIO_TO_FRAUD = 15

# splitting by class
fraud = df[df.label == 1]
clean = df[df.label == 0]

# concatenate with fraud transactions into a single dataframe
visualisation_initial = pd.concat([fraud, clean])
column_names = list(visualisation_initial.drop('label', axis=1).columns)

# isolate features from labels 
features, labels = visualisation_initial.drop('label', axis=1).values, \
                   visualisation_initial.label.values
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

def tsne_scatter(features, labels, dimensions=2, save_as='graph.png'):
    if dimensions not in (2, 3):
        raise ValueError('tsne_scatter can only plot in 2d or 3d (What are you? An alien that can visualise >3d?). Make sure the "dimensions" argument is in (2, 3)')

    # t-SNE dimensionality reduction
    features_embedded = TSNE(n_components=dimensions, random_state=RANDOM_SEED).fit_transform(features)
    
    # initialising the plot
    fig, ax = plt.subplots(figsize=(8,8))
    
    # counting dimensions
    if dimensions == 3: ax = fig.add_subplot(111, projection='3d')

    # plotting data
    ax.scatter(
        *zip(*features_embedded[np.where(labels==1)]),
        marker='o',
        color='r',
        s=2,
        alpha=0.7,
        label='Fraud'
    )
    ax.scatter(
        *zip(*features_embedded[np.where(labels==0)]),
        marker='o',
        color='g',
        s=2,
        alpha=0.3,
        label='Clean'
    )

    # storing it to be displayed later
    plt.legend(loc='best')
    plt.savefig(save_as);
    plt.show;

tsne_scatter(features, labels, dimensions=2, save_as='tsne_initial_2d.png')
# Out:
# <div id='a10cb6ee-4d03-4629-9b6e-229a7288c132'></div>

# %%
clean.shape ,fraud.shape
# Out:
# ((2097, 9), (2097, 9))

# %%
X_train = clean.iloc[:].drop('label', axis=1)

X_test = clean.iloc[:].append(fraud).sample(frac=1)
# Out:
# <ipython-input-54-bd97f21b5848>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   X_test = clean.iloc[:].append(fraud).sample(frac=1)

# %%
X_train.shape,X_test.shape
# Out:
# ((2097, 8), (4194, 9))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val = train_test_split(X_train, test_size=0.2,
                                  random_state=RANDOM_SEED)

X_test, y_test = X_test.drop('label', axis=1).values, X_test.label.values
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn.pipeline import Pipeline

# configure our pipeline
pipeline = Pipeline([('normalizer', Normalizer()),
                     ('scaler', MinMaxScaler())])
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1677, 8), (420, 8), (4194, 8))

# %%
# get normalization parameters by fitting to the training data
pipeline.fit(X_train);
# transform the training and validation data with these parameters
X_train_transformed = pipeline.transform(X_train)
X_validate_transformed = pipeline.transform(X_val)

# %%
history = autoencoder.fit(
    X_train_transformed, X_train_transformed,
    shuffle=True,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    validation_data=(X_validate_transformed, X_validate_transformed)
);
# Out:
# Epoch 1/100
# 105/105 [==============================] - 1s 7ms/step - loss: 0.0019 - acc: 0.7138 - val_loss: 8.8631e-04 - val_acc: 0.7762
# Epoch 2/100
# 105/105 [==============================] - 1s 6ms/step - loss: 5.6312e-04 - acc: 0.7931 - val_loss: 3.6184e-04 - val_acc: 0.7786
# Epoch 3/100
# 105/105 [==============================] - 1s 7ms/step - loss: 3.3386e-04 - acc: 0.8169 - val_loss: 2.7352e-04 - val_acc: 0.7833
# Epoch 4/100
# 105/105 [==============================] - 1s 10ms/step - loss: 3.3879e-04 - acc: 0.8324 - val_loss: 2.7722e-04 - val_acc: 0.7690
# Epoch 5/100
# 105/105 [==============================] - 1s 10ms/step - loss: 2.1960e-04 - acc: 0.8318 - val_loss: 2.6049e-04 - val_acc: 0.8310
# Epoch 6/100
# 105/105 [==============================] - 1s 9ms/step - loss: 2.0430e-04 - acc: 0.8301 - val_loss: 1.7316e-04 - val_acc: 0.8143
# Epoch 7/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.9751e-04 - acc: 0.8366 - val_loss: 1.7711e-04 - val_acc: 0.8214
# Epoch 8/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.8966e-04 - acc: 0.8408 - val_loss: 2.7641e-04 - val_acc: 0.8167
# Epoch 9/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.7203e-04 - acc: 0.8468 - val_loss: 1.8698e-04 - val_acc: 0.8119
# Epoch 10/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.4675e-04 - acc: 0.8456 - val_loss: 2.6051e-04 - val_acc: 0.8381
# Epoch 11/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.8021e-04 - acc: 0.8354 - val_loss: 2.4549e-04 - val_acc: 0.8190
# Epoch 12/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.7642e-04 - acc: 0.8360 - val_loss: 5.1955e-04 - val_acc: 0.7500
# Epoch 13/100
# 105/105 [==============================] - 1s 7ms/step - loss: 3.2747e-04 - acc: 0.8265 - val_loss: 1.6976e-04 - val_acc: 0.8476
# Epoch 14/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.1991e-04 - acc: 0.8485 - val_loss: 1.2117e-04 - val_acc: 0.8310
# Epoch 15/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.2845e-04 - acc: 0.8432 - val_loss: 1.2059e-04 - val_acc: 0.8238
# Epoch 16/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.6873e-04 - acc: 0.8539 - val_loss: 1.6885e-04 - val_acc: 0.8000
# Epoch 17/100
# 105/105 [==============================] - 1s 7ms/step - loss: 2.6223e-04 - acc: 0.8348 - val_loss: 3.3437e-04 - val_acc: 0.8214
# Epoch 18/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.6891e-04 - acc: 0.8372 - val_loss: 2.2185e-04 - val_acc: 0.7976
# Epoch 19/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.7208e-04 - acc: 0.8402 - val_loss: 1.6460e-04 - val_acc: 0.8000
# Epoch 20/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.9872e-04 - acc: 0.8265 - val_loss: 2.4045e-04 - val_acc: 0.7976
# Epoch 21/100
# 105/105 [==============================] - 1s 10ms/step - loss: 1.3488e-04 - acc: 0.8396 - val_loss: 1.7302e-04 - val_acc: 0.8381
# Epoch 22/100
# 105/105 [==============================] - 1s 10ms/step - loss: 2.4827e-04 - acc: 0.8241 - val_loss: 2.5998e-04 - val_acc: 0.7833
# Epoch 23/100
# 105/105 [==============================] - 1s 9ms/step - loss: 1.7579e-04 - acc: 0.8301 - val_loss: 1.2511e-04 - val_acc: 0.8619
# Epoch 24/100
# 104/105 [============================>.] - ETA: 0s - loss: 1.7319e-04 - acc: 0.8456Restoring model weights from the end of the best epoch: 14.
# 105/105 [==============================] - 1s 7ms/step - loss: 1.7282e-04 - acc: 0.8438 - val_loss: 1.8120e-04 - val_acc: 0.8167
# Epoch 24: early stopping

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Normalizer was fitted with feature names
#   warnings.warn(
# 132/132 [==============================] - 0s 3ms/step

# %%
# calculating the mean squared error reconstruction loss per row in the numpy array
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
clean.shape, fraud.shape
# Out:
# ((2097, 9), (2097, 9))

# %%
autoencoder.save('/content/drive/MyDrive/csv/model_20.h5')

# %%
test_data
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           2.51         53.28           0.7          32.54     2662.0
# 1           2.66         55.24           0.7          34.45     2819.0
# 2           1.72         42.74           0.7          22.23     1819.0
# 3           2.20         49.15           0.7          28.50     2332.0
# 4           2.06         47.28           0.7          26.67     2182.0
# ...          ...           ...           ...            ...        ...
# 7384        2.12         48.08           0.7          27.45     2246.0
# 7385        1.48         39.63           0.7          19.19     1570.0
# 7386        1.56         40.61           0.7          20.15     1649.0
# 7387        1.59         40.99           0.7          20.52     1679.0
# 7388        1.70         42.51           0.7          22.01     1801.0
#
#       motor_temp  motor_vibe  type  label
# 0          69.58        3.48     0      0
# 1          71.32        3.57     0      0
# 2          60.21        3.01     0      0
# 3          65.91        3.30     0      0
# 4          64.24        3.21     0      0
# ...          ...         ...   ...    ...
# 7384       64.96        3.25     7      0
# 7385       57.44        2.87     7      0
# 7386       58.32        2.92     7      0
# 7387       58.66        2.93     7      0
# 7388       60.01        3.00     7      0
#
# [7389 rows x 9 columns]

# %%
cond = (test_data['type'] == 2)
X_test = test_data.loc[cond, :].drop('label', axis=1)

# %%
X_test
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 2403        0.81         53.29           0.7          12.90     2903.0
# 2404        0.75         50.89           0.7          12.05     2711.0
# 2405        0.98         60.96           0.7          15.63     3517.0
# 2406        0.34         32.33           0.7           5.45     1226.0
# 2407        0.80         53.18           0.7          12.86     2894.0
# ...          ...           ...           ...            ...        ...
# 3496        0.60         43.86           0.7           9.55     2149.0
# 3497        0.96         60.06           0.7          15.31     3445.0
# 3498        0.82         54.09           0.7          13.19     2967.0
# 3499        0.65         46.31           0.7          10.42     2345.0
# 3500        0.35         32.86           0.7           5.64     1269.0
#
#       motor_temp  motor_vibe  type
# 2403       69.26        2.91     2
# 2404       67.12        2.81     2
# 2405       76.08        3.25     2
# 2406       50.62        1.98     2
# 2407       69.16        2.91     2
# ...          ...         ...   ...
# 3496       60.88        2.49     2
# 3497       75.28        3.21     2
# 3498       69.97        2.95     2
# 3499       63.06        2.60     2
# 3500       51.10        2.01     2
#
# [1098 rows x 8 columns]

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
# 35/35 [==============================] - 0s 2ms/step

# %%
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
mean_mse = np.mean(mse)
std_mse = np.std(mse)

print("Mean MSE:", mean_mse)
print("Standard deviation of MSE:", std_mse)
# Out:
# Mean MSE: 211.20081353949678
# Standard deviation of MSE: 2825.178015235189

# %%
sns.boxplot(x=mse)

# q3와 iqr 계산
q1, q3 = np.percentile(mse, [25, 75])
iqr = q3 - q1

# q3+1.5*iqr 값 계산
upper_bound = q3 + 1.5 * iqr

print("Upper bound: ", upper_bound)
# Out:
# Upper bound:  0.04546188672159242

# %%
import seaborn as sns

plt.hist(mse, bins=100)
plt.xlabel('mse')
plt.ylabel('count')
plt.show()

# %%
min(mse),max(mse)
# Out:
# (0.013142528117953644, 0.3494969275135377)

# %%
test_data
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           2.51         53.28           0.7          32.54     2662.0
# 1           2.66         55.24           0.7          34.45     2819.0
# 2           1.72         42.74           0.7          22.23     1819.0
# 3           2.20         49.15           0.7          28.50     2332.0
# 4           2.06         47.28           0.7          26.67     2182.0
# ...          ...           ...           ...            ...        ...
# 7384        2.12         48.08           0.7          27.45     2246.0
# 7385        1.48         39.63           0.7          19.19     1570.0
# 7386        1.56         40.61           0.7          20.15     1649.0
# 7387        1.59         40.99           0.7          20.52     1679.0
# 7388        1.70         42.51           0.7          22.01     1801.0
#
#       motor_temp  motor_vibe  type  label
# 0          69.58        3.48     0      0
# 1          71.32        3.57     0      0
# 2          60.21        3.01     0      0
# 3          65.91        3.30     0      0
# 4          64.24        3.21     0      0
# ...          ...         ...   ...    ...
# 7384       64.96        3.25     7      0
# 7385       57.44        2.87     7      0
# 7386       58.32        2.92     7      0
# 7387       58.66        2.93     7      0
# 7388       60.01        3.00     7      0
#
# [7389 rows x 9 columns]

# %%
test_data.loc[cond, 'label'] = np.where(mse >= 0.008, 1, 0)

# %%
test_data['label'].value_counts()
# Out:
# 0    7058
# 1     331
# Name: label, dtype: int64

# %%
df = pd.read_csv('/content/drive/MyDrive/csv/train_data.csv')

# %%
# 설비 번호 [0, 4, 5, 6, 7]: 30HP(마력)
# 설비 번호 1: 20HP
# 설비 번호 2: 10HP
# 설비 번호 3: 50HP

mapping = {0:1, 1:0, 2:1, 3:1, 4:1, 5:1, 6:1, 7:1}

df['label'] = df['type'].map(mapping)
df
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           1.59         41.00           0.7          20.53     1680.0
# 1           2.97         59.28           0.7          38.40     3142.0
# 2           1.91         45.29           0.7          24.73     2023.0
# 3           2.37         51.33           0.7          30.63     2506.0
# 4           1.90         45.21           0.7          24.65     2017.0
# ...          ...           ...           ...            ...        ...
# 2458        2.28         50.20           0.7          29.53     2416.0
# 2459        2.04         46.94           0.7          26.34     2155.0
# 2460        1.19         35.74           0.7          15.39     1259.0
# 2461        1.21         36.00           0.7          15.64     1280.0
# 2462        2.72         55.99           0.7          35.19     2879.0
#
#       motor_temp  motor_vibe  type  label
# 0          58.67        2.93     0      1
# 1          74.91        3.75     0      1
# 2          62.48        3.12     0      1
# 3          67.84        3.39     0      1
# 4          62.41        3.12     0      1
# ...          ...         ...   ...    ...
# 2458       66.84        3.34     7      1
# 2459       63.94        3.20     7      1
# 2460       53.99        2.70     7      1
# 2461       54.22        2.71     7      1
# 2462       71.99        3.60     7      1
#
# [2463 rows x 9 columns]

# %%
df['label'].value_counts()
# Out:
# 1    2094
# 0     369
# Name: label, dtype: int64

# %%
from imblearn.over_sampling import SMOTE, ADASYN

X = df.drop('label', axis=1)
y = df.loc[:,'label']

#SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

df = pd.concat([X_resampled, y_resampled], axis=1)

#ADASYN
#adasyn = ADASYN()
#X_resampled, y_resampled = adasyn.fit_resample(X, y)
#df = pd.concat([X_resampled, y_resampled], axis=1)

# %%
# manual parameter 
RATIO_TO_FRAUD = 15

# splitting by class
fraud = df[df.label == 1]
clean = df[df.label == 0]

# concatenate with fraud transactions into a single dataframe
visualisation_initial = pd.concat([fraud, clean])
column_names = list(visualisation_initial.drop('label', axis=1).columns)

# isolate features from labels 
features, labels = visualisation_initial.drop('label', axis=1).values, \
                   visualisation_initial.label.values
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

def tsne_scatter(features, labels, dimensions=2, save_as='graph.png'):
    if dimensions not in (2, 3):
        raise ValueError('tsne_scatter can only plot in 2d or 3d (What are you? An alien that can visualise >3d?). Make sure the "dimensions" argument is in (2, 3)')

    # t-SNE dimensionality reduction
    features_embedded = TSNE(n_components=dimensions, random_state=RANDOM_SEED).fit_transform(features)
    
    # initialising the plot
    fig, ax = plt.subplots(figsize=(8,8))
    
    # counting dimensions
    if dimensions == 3: ax = fig.add_subplot(111, projection='3d')

    # plotting data
    ax.scatter(
        *zip(*features_embedded[np.where(labels==1)]),
        marker='o',
        color='r',
        s=2,
        alpha=0.7,
        label='Fraud'
    )
    ax.scatter(
        *zip(*features_embedded[np.where(labels==0)]),
        marker='o',
        color='g',
        s=2,
        alpha=0.3,
        label='Clean'
    )

    # storing it to be displayed later
    plt.legend(loc='best')
    plt.savefig(save_as);
    plt.show;

tsne_scatter(features, labels, dimensions=2, save_as='tsne_initial_2d.png')
# Out:
# <div id='dc9c24a3-b915-4c0b-95d1-eee0c44ef37e'></div>

# %%
clean.shape, fraud.shape
# Out:
# ((2094, 9), (2094, 9))

# %%
X_train = clean.iloc[:].drop('label', axis=1)

X_test = clean.iloc[:].append(fraud).sample(frac=1)
# Out:
# <ipython-input-79-bd97f21b5848>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   X_test = clean.iloc[:].append(fraud).sample(frac=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val = train_test_split(X_train, test_size=0.2,
                                  random_state=RANDOM_SEED)

X_test, y_test = X_test.drop('label', axis=1).values, X_test.label.values
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn.pipeline import Pipeline

# configure our pipeline
pipeline = Pipeline([('normalizer', Normalizer()),
                     ('scaler', MinMaxScaler())])
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1675, 8), (419, 8), (4188, 8))

# %%
# get normalization parameters by fitting to the training data
pipeline.fit(X_train);
# transform the training and validation data with these parameters
X_train_transformed = pipeline.transform(X_train)
X_validate_transformed = pipeline.transform(X_val)

# %%
history = autoencoder.fit(
    X_train_transformed, X_train_transformed,
    shuffle=True,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    validation_data=(X_validate_transformed, X_validate_transformed)
);
# Out:
# Epoch 1/100
# 105/105 [==============================] - 1s 7ms/step - loss: 0.0076 - acc: 0.7821 - val_loss: 9.0167e-04 - val_acc: 0.7733
# Epoch 2/100
# 105/105 [==============================] - 1s 6ms/step - loss: 7.6517e-04 - acc: 0.7869 - val_loss: 7.5019e-04 - val_acc: 0.7685
# Epoch 3/100
# 105/105 [==============================] - 1s 9ms/step - loss: 6.5344e-04 - acc: 0.7964 - val_loss: 4.5314e-04 - val_acc: 0.8950
# Epoch 4/100
# 105/105 [==============================] - 1s 10ms/step - loss: 4.2143e-04 - acc: 0.8078 - val_loss: 3.7528e-04 - val_acc: 0.7685
# Epoch 5/100
# 105/105 [==============================] - 1s 10ms/step - loss: 2.8548e-04 - acc: 0.8209 - val_loss: 2.5975e-04 - val_acc: 0.7900
# Epoch 6/100
# 105/105 [==============================] - 1s 7ms/step - loss: 2.3703e-04 - acc: 0.8155 - val_loss: 2.9760e-04 - val_acc: 0.7709
# Epoch 7/100
# 105/105 [==============================] - 1s 7ms/step - loss: 2.0451e-04 - acc: 0.8179 - val_loss: 2.0311e-04 - val_acc: 0.7900
# Epoch 8/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.6064e-04 - acc: 0.8167 - val_loss: 1.3147e-04 - val_acc: 0.7947
# Epoch 9/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.5031e-04 - acc: 0.8078 - val_loss: 1.7045e-04 - val_acc: 0.8234
# Epoch 10/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.5065e-04 - acc: 0.8167 - val_loss: 1.2185e-04 - val_acc: 0.8258
# Epoch 11/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.5467e-04 - acc: 0.8215 - val_loss: 2.2402e-04 - val_acc: 0.8305
# Epoch 12/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.3246e-04 - acc: 0.8155 - val_loss: 1.4020e-04 - val_acc: 0.7900
# Epoch 13/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.2187e-04 - acc: 0.8293 - val_loss: 1.7521e-04 - val_acc: 0.8735
# Epoch 14/100
# 105/105 [==============================] - 1s 7ms/step - loss: 2.0622e-04 - acc: 0.8251 - val_loss: 1.0533e-04 - val_acc: 0.8401
# Epoch 15/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.6064e-04 - acc: 0.8364 - val_loss: 1.0684e-04 - val_acc: 0.8950
# Epoch 16/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.2200e-04 - acc: 0.8239 - val_loss: 9.4479e-05 - val_acc: 0.8305
# Epoch 17/100
# 105/105 [==============================] - 1s 7ms/step - loss: 1.1169e-04 - acc: 0.8346 - val_loss: 1.2128e-04 - val_acc: 0.8902
# Epoch 18/100
#  97/105 [==========================>...] - ETA: 0s - loss: 1.2430e-04 - acc: 0.8344Restoring model weights from the end of the best epoch: 8.
# 105/105 [==============================] - 1s 7ms/step - loss: 1.2530e-04 - acc: 0.8346 - val_loss: 1.0774e-04 - val_acc: 0.8329
# Epoch 18: early stopping

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
#  37/131 [=======>......................] - ETA: 0s
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Normalizer was fitted with feature names
#   warnings.warn(
# 131/131 [==============================] - 0s 3ms/step

# %%
# calculating the mean squared error reconstruction loss per row in the numpy array
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
clean.shape, fraud.shape
# Out:
# ((2094, 9), (2094, 9))

# %%
clean = mse[y_test==0]
fraud = mse[y_test==1]

plt.subplot(1,2,1)
plt.hist(clean, bins=50, density=True, label='clean', alpha=.6, color='green')
plt.subplot(1,2,2)
plt.hist(fraud, bins=50, density=True, label='fraud', alpha=.6, color='red')
plt.show()
# Out:
# <ipython-input-86-bbcf3b465143>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %%
clean.max(), fraud.min()
# Out:
# (0.001131204722677085, 0.0003281075236823245)

# %%
autoencoder.save('/content/drive/MyDrive/csv/model_10.h5')

# %%
cond = (test_data['type'] == 1)
X_test = test_data.loc[cond, :].drop('label', axis=1)

# %%
len(X_test)
# Out:
# 1107

# %%
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
# 35/35 [==============================] - 0s 2ms/step

# %%
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
mean_mse = np.mean(mse)
std_mse = np.std(mse)

print("Mean MSE:", mean_mse)
print("Standard deviation of MSE:", std_mse)
# Out:
# Mean MSE: 0.00010522441259824288
# Standard deviation of MSE: 0.00011082121624397362

# %%
sns.boxplot(x=mse)

# q3와 iqr 계산
q1, q3 = np.percentile(mse, [25, 75])
iqr = q3 - q1

# q3+1.5*iqr 값 계산
upper_bound = q3 + 1.5 * iqr

print("Upper bound: ", upper_bound)
# Out:
# Upper bound:  0.002701176986168452

# %%
import seaborn as sns

plt.hist(mse, bins=100)
plt.xlabel('mse')
plt.ylabel('count')
plt.show()

# %%
plt.boxplot(mse)
plt.show()

# %%
sns.boxplot(x=mse)

# q3와 iqr 계산
q1, q3 = np.percentile(mse, [25, 75])
iqr = q3 - q1

# q3+1.5*iqr 값 계산
upper_bound = q3 + 1.5 * iqr

print("Upper bound: ", upper_bound)
# Out:
# Upper bound:  0.002701176986168452

# %%
mse.max()
# Out:
# 0.38889637044326336

# %%
sns.boxplot(x=mse)

# q3와 iqr 계산
q1, q3 = np.percentile(mse, [25, 75])
iqr = q3 - q1

# q3+1.5*iqr 값 계산
upper_bound = q3 + 1.5 * iqr

print("Upper bound: ", upper_bound)
threshold=upper_bound
# Out:
# Upper bound:  0.00011911265585108646

# %%
 test_data.loc[cond, 'label'] = np.where(mse >= 0.008, 1, 0)

# %%
test_data['label'].value_counts()
# Out:
# 0    7058
# 1     331
# Name: label, dtype: int64

# %%
df = pd.read_csv('/content/drive/MyDrive/csv/train_data.csv')

# %%
# 설비 번호 [0, 4, 5, 6, 7]: 30HP(마력)
# 설비 번호 1: 20HP
# 설비 번호 2: 10HP
# 설비 번호 3: 50HP

mapping = {0:1, 1:1, 2:1, 3:0, 4:1, 5:1, 6:1, 7:1}

df['label'] = df['type'].map(mapping)
df
# Out:
#       air_inflow  air_end_temp  out_pressure  motor_current  motor_rpm  \
# 0           1.59         41.00           0.7          20.53     1680.0
# 1           2.97         59.28           0.7          38.40     3142.0
# 2           1.91         45.29           0.7          24.73     2023.0
# 3           2.37         51.33           0.7          30.63     2506.0
# 4           1.90         45.21           0.7          24.65     2017.0
# ...          ...           ...           ...            ...        ...
# 2458        2.28         50.20           0.7          29.53     2416.0
# 2459        2.04         46.94           0.7          26.34     2155.0
# 2460        1.19         35.74           0.7          15.39     1259.0
# 2461        1.21         36.00           0.7          15.64     1280.0
# 2462        2.72         55.99           0.7          35.19     2879.0
#
#       motor_temp  motor_vibe  type  label
# 0          58.67        2.93     0      1
# 1          74.91        3.75     0      1
# 2          62.48        3.12     0      1
# 3          67.84        3.39     0      1
# 4          62.41        3.12     0      1
# ...          ...         ...   ...    ...
# 2458       66.84        3.34     7      1
# 2459       63.94        3.20     7      1
# 2460       53.99        2.70     7      1
# 2461       54.22        2.71     7      1
# 2462       71.99        3.60     7      1
#
# [2463 rows x 9 columns]

# %%
df['label'].value_counts()
# Out:
# 1    2157
# 0     306
# Name: label, dtype: int64

# %%
from imblearn.over_sampling import SMOTE, ADASYN

X = df.drop('label', axis=1)
y = df.loc[:,'label']

#SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

df = pd.concat([X_resampled, y_resampled], axis=1)

#ADASYN
#adasyn = ADASYN()
#X_resampled, y_resampled = adasyn.fit_resample(X, y)
#df = pd.concat([X_resampled, y_resampled], axis=1)

# %%
# manual parameter 
RATIO_TO_FRAUD = 15

# splitting by class
fraud = df[df.label == 1]
clean = df[df.label == 0]

# concatenate with fraud transactions into a single dataframe
visualisation_initial = pd.concat([fraud, clean])
column_names = list(visualisation_initial.drop('label', axis=1).columns)

# isolate features from labels 
features, labels = visualisation_initial.drop('label', axis=1).values, \
                   visualisation_initial.label.values
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

def tsne_scatter(features, labels, dimensions=2, save_as='graph.png'):
    if dimensions not in (2, 3):
        raise ValueError('tsne_scatter can only plot in 2d or 3d (What are you? An alien that can visualise >3d?). Make sure the "dimensions" argument is in (2, 3)')

    # t-SNE dimensionality reduction
    features_embedded = TSNE(n_components=dimensions, random_state=RANDOM_SEED).fit_transform(features)
    
    # initialising the plot
    fig, ax = plt.subplots(figsize=(8,8))
    
    # counting dimensions
    if dimensions == 3: ax = fig.add_subplot(111, projection='3d')

    # plotting data
    ax.scatter(
        *zip(*features_embedded[np.where(labels==1)]),
        marker='o',
        color='r',
        s=2,
        alpha=0.7,
        label='Fraud'
    )
    ax.scatter(
        *zip(*features_embedded[np.where(labels==0)]),
        marker='o',
        color='g',
        s=2,
        alpha=0.3,
        label='Clean'
    )

    # storing it to be displayed later
    plt.legend(loc='best')
    plt.savefig(save_as);
    plt.show;

tsne_scatter(features, labels, dimensions=2, save_as='tsne_initial_2d.png')
# Out:
# <div id='bfcbdedc-232c-4d8d-987e-114c4636bffb'></div>

# %%
clean.shape, fraud.shape
# Out:
# ((2157, 9), (2157, 9))

# %%
X_train = clean.iloc[:].drop('label', axis=1)

X_test = clean.iloc[:].append(fraud).sample(frac=1)
# Out:
# <ipython-input-103-bd97f21b5848>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   X_test = clean.iloc[:].append(fraud).sample(frac=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((2157, 8), (4314, 9))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val = train_test_split(X_train, test_size=0.2,
                                  random_state=RANDOM_SEED)

X_test, y_test = X_test.drop('label', axis=1).values, X_test.label.values
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn.pipeline import Pipeline

# configure our pipeline
pipeline = Pipeline([('normalizer', Normalizer()),
                     ('scaler', MinMaxScaler())])
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1725, 8), (432, 8), (4314, 8))

# %%
# get normalization parameters by fitting to the training data
pipeline.fit(X_train);
# transform the training and validation data with these parameters
X_train_transformed = pipeline.transform(X_train)
X_validate_transformed = pipeline.transform(X_val)

# %%
history = autoencoder.fit(
    X_train_transformed, X_train_transformed,
    shuffle=True,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    validation_data=(X_validate_transformed, X_validate_transformed)
);
# Out:
# Epoch 1/100
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0025 - acc: 0.8191 - val_loss: 2.8044e-04 - val_acc: 0.8565
# Epoch 2/100
# 108/108 [==============================] - 1s 7ms/step - loss: 3.0866e-04 - acc: 0.8719 - val_loss: 3.0997e-04 - val_acc: 0.8449
# Epoch 3/100
# 108/108 [==============================] - 1s 7ms/step - loss: 1.8259e-04 - acc: 0.8904 - val_loss: 1.1742e-04 - val_acc: 0.8935
# Epoch 4/100
# 108/108 [==============================] - 1s 7ms/step - loss: 1.4580e-04 - acc: 0.8945 - val_loss: 9.2878e-05 - val_acc: 0.8843
# Epoch 5/100
# 108/108 [==============================] - 1s 7ms/step - loss: 1.1347e-04 - acc: 0.8887 - val_loss: 8.6161e-05 - val_acc: 0.8843
# Epoch 6/100
# 108/108 [==============================] - 1s 7ms/step - loss: 1.2423e-04 - acc: 0.8939 - val_loss: 1.3270e-04 - val_acc: 0.9005
# Epoch 7/100
# 108/108 [==============================] - 1s 7ms/step - loss: 1.8623e-04 - acc: 0.8887 - val_loss: 5.2426e-04 - val_acc: 0.8565
# Epoch 8/100
# 108/108 [==============================] - 1s 6ms/step - loss: 2.1601e-04 - acc: 0.8858 - val_loss: 8.8846e-05 - val_acc: 0.8704
# Epoch 9/100
# 108/108 [==============================] - 1s 7ms/step - loss: 1.1837e-04 - acc: 0.8951 - val_loss: 1.2030e-04 - val_acc: 0.8958
# Epoch 10/100
# 108/108 [==============================] - 1s 9ms/step - loss: 1.3064e-04 - acc: 0.8875 - val_loss: 1.5669e-04 - val_acc: 0.8935
# Epoch 11/100
# 108/108 [==============================] - 1s 9ms/step - loss: 1.1355e-04 - acc: 0.8800 - val_loss: 1.1257e-04 - val_acc: 0.8958
# Epoch 12/100
# 108/108 [==============================] - 1s 9ms/step - loss: 7.5536e-05 - acc: 0.8904 - val_loss: 1.8215e-04 - val_acc: 0.8657
# Epoch 13/100
# 104/108 [===========================>..] - ETA: 0s - loss: 7.3658e-05 - acc: 0.8792Restoring model weights from the end of the best epoch: 3.
# 108/108 [==============================] - 1s 8ms/step - loss: 7.3151e-05 - acc: 0.8783 - val_loss: 7.8475e-05 - val_acc: 0.8750
# Epoch 13: early stopping

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Normalizer was fitted with feature names
#   warnings.warn(
# 135/135 [==============================] - 0s 3ms/step

# %%
# calculating the mean squared error reconstruction loss per row in the numpy array
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
clean.shape, fraud.shape
# Out:
# ((2157, 9), (2157, 9))

# %%
clean = mse[y_test==0]
fraud = mse[y_test==1]

plt.subplot(1,2,1)
plt.hist(clean, bins=50, density=True, label='clean', alpha=.6, color='green')
plt.subplot(1,2,2)
plt.hist(fraud, bins=50, density=True, label='fraud', alpha=.6, color='red')
plt.show()

# %%
clean.max(), fraud.min()
# Out:
# (air_inflow          6.22
#  air_end_temp       64.96
#  out_pressure        0.70
#  motor_current      72.00
#  motor_rpm        3557.00
#  motor_temp         80.52
#  motor_vibe          5.18
#  type                3.00
#  label               0.00
#  dtype: float64,
#  air_inflow          0.33
#  air_end_temp       32.03
#  out_pressure        0.70
#  motor_current       5.34
#  motor_rpm        1201.00
#  motor_temp         50.36
#  motor_vibe          1.97
#  type                0.00
#  label               1.00
#  dtype: float64)

# %%
autoencoder.save('/content/drive/MyDrive/SPARK_AIVLE/models/model_50.h5')

# %%
cond = (test_data['type'] == 3)
X_test = test_data.loc[cond, :].drop('label', axis=1)

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
# 29/29 [==============================] - 0s 2ms/step

# %%
# calculating the mean squared error reconstruction loss per row in the numpy array
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
import seaborn as sns

plt.hist(mse, bins=100)
plt.xlabel('mse')
plt.ylabel('count')
plt.show()

# %%
sns.boxplot(x=mse)

# q3와 iqr 계산
q1, q3 = np.percentile(mse, [25, 75])
iqr = q3 - q1

# q3+1.5*iqr 값 계산
upper_bound = q3 + 1.5 * iqr

print("Upper bound: ", upper_bound)
# Out:
# Upper bound:  0.23952749726304806

# %%
test_data.loc[cond, 'label'] = np.where(mse >= 0.01, 1, 0)

# %%
test_data['label'].value_counts()
# Out:
# 0    7033
# 1     356
# Name: label, dtype: int64

# %%
submit=pd.read_csv('/content/drive/MyDrive/csv/answer_sample.csv')

# %%
submit
# Out:
#       type  label
# 0        0     -1
# 1        0     -1
# 2        0     -1
# 3        0     -1
# 4        0     -1
# ...    ...    ...
# 7384     7     -1
# 7385     7     -1
# 7386     7     -1
# 7387     7     -1
# 7388     7     -1
#
# [7389 rows x 2 columns]

# %%
submit['label'] = test_data['label']

# %%
submit['label'].value_counts()
# Out:
# 0    7033
# 1     356
# Name: label, dtype: int64

# %%
submit.to_csv('/content/drive/MyDrive/csv/submit9.csv',index=False)

# %%
############################################################################################################################
